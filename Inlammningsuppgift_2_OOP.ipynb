# %% [markdown]
# Inlämningsuppgift2 OOP version
#
# Object Oriented version of the number guessing game.
#
# Use of AI:
#
# Help in structure of creating the notebook with folder-structure, suggestions of function separation, overall system red-thread logic and first structure UML-diagram.
#
# Running the program
#
# - Simply run the "%run Inlamuppgift2_OOP/mainOOP.py" code below

# %% [markdown]
# Structure (UML)
#
# Player
# - player_name : str
# - player_birtdate : str
# - player_age : int
# + input_player_name()
# + input_player_birthdate()
# + is_adult()
#
#
#
# LuckyNumberRound
# - lucky_list : list
# - lucky_number : int
# - tries : int
# + generate_lucky_list()
# + generate_lucky_number()
# + filter_list()
# + ask_to_play_again()
# + play_round()
#
# Game
# - player : Player
# + play()

# %%
# %run Inlamuppgift2_OOP/mainOOP.py
